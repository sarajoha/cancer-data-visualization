# %%
import pygal

# %%
from IPython.display import display, SVG

# %%
xvals = [0, 1, 3, 5, 6, 7, 9, 11, 12, 15]

# %%
yvals = [4, 3, 1, 2, 2, 4, 5, 2, 1, 4]

# %%
lineplot = pygal.Line(height=400)

# %%
lineplot.title = 'My line plot'

# %%
lineplot.x_labels = xvals

# %%
lineplot.add('Data', yvals)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/miniconda3/lib/python3.7/site-packages/pygal/graph/base.py in _repr_png_(self)
#     232     def _repr_png_(self):
#     233         """Display png in IPython notebook"""
# --> 234         return self.render_to_png()
#
# ~/miniconda3/lib/python3.7/site-packages/pygal/graph/public.py in render_to_png(self, filename, dpi, **kwargs)
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#     117         """Render the graph, convert it to png and write it to filename"""
# --> 118         import cairosvg
#     119         return cairosvg.svg2png(
#     120             bytestring=self.render(**kwargs), write_to=filename, dpi=dpi)
#
# ModuleNotFoundError: No module named 'cairosvg'

# %%
display(SVG(lineplot.render(disable_xml_declaration=True)))
